# %% [markdown]
# # Importing Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input

# %% [markdown]
# # EDA

# %% [markdown]
# Reading data

# %%
df = pd.read_csv('/kaggle/input/ann-car-sales-price-prediction/car_purchasing.csv', encoding='ISO-8859-1')

# %%
df.head()
# Out:
#      customer name                                    customer e-mail  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1    Harlan Barnes                                eu.dolor@diam.co.uk
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3  Jade Cunningham                            malesuada@dignissim.com
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
#
#         country  gender        age  annual Salary  credit card debt  \
# 0      Bulgaria       0  41.851720    62812.09301      11609.380910
# 1        Belize       0  40.870623    66646.89292       9572.957136
# 2       Algeria       1  43.152897    53798.55112      11160.355060
# 3  Cook Islands       1  58.271369    79370.03798      14426.164850
# 4        Brazil       1  57.313749    59729.15130       5358.712177
#
#      net worth  car purchase amount
# 0  238961.2505          35321.45877
# 1  530973.9078          45115.52566
# 2  638467.1773          42925.70921
# 3  548599.0524          67422.36313
# 4  560304.0671          55915.46248

# %% [markdown]
# ### Drop unneeded col

# %%
df.drop(['customer name', 'customer e-mail', 'country','gender'], axis=1, inplace= True)

# %%
df
# Out:
#            age  annual Salary  credit card debt    net worth  \
# 0    41.851720    62812.09301      11609.380910  238961.2505
# 1    40.870623    66646.89292       9572.957136  530973.9078
# 2    43.152897    53798.55112      11160.355060  638467.1773
# 3    58.271369    79370.03798      14426.164850  548599.0524
# 4    57.313749    59729.15130       5358.712177  560304.0671
# ..         ...            ...               ...          ...
# 495  41.462515    71942.40291       6995.902524  541670.1016
# 496  37.642000    56039.49793      12301.456790  360419.0988
# 497  53.943497    68888.77805      10611.606860  764531.3203
# 498  59.160509    49811.99062      14013.034510  337826.6382
# 499  46.731152    61370.67766       9391.341628  462946.4924
#
#      car purchase amount
# 0            35321.45877
# 1            45115.52566
# 2            42925.70921
# 3            67422.36313
# 4            55915.46248
# ..                   ...
# 495          48901.44342
# 496          31491.41457
# 497          64147.28888
# 498          45442.15353
# 499          45107.22566
#
# [500 rows x 5 columns]

# %% [markdown]
# Get info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  500 non-null    float64
#  1   annual Salary        500 non-null    float64
#  2   credit card debt     500 non-null    float64
#  3   net worth            500 non-null    float64
#  4   car purchase amount  500 non-null    float64
# dtypes: float64(5)
# memory usage: 19.7 KB

# %%
df.describe().round(2).T
# Out:
#                      count       mean        std      min        25%  \
# age                  500.0      46.24       7.98     20.0      40.95
# annual Salary        500.0   62127.24   11703.38  20000.0   54391.98
# credit card debt     500.0    9607.65    3489.19    100.0    7397.52
# net worth            500.0  431475.71  173536.76  20000.0  299824.20
# car purchase amount  500.0   44209.80   10773.18   9000.0   37629.90
#
#                            50%        75%        max
# age                      46.05      51.61       70.0
# annual Salary         62915.50   70117.86   100000.0
# credit card debt       9655.04   11798.87    20000.0
# net worth            426750.12  557324.48  1000000.0
# car purchase amount   43997.78   51254.71    80000.0

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ### Define feature(x) & target(y)

# %%
X = df.drop('car purchase amount', axis=1)
y = df['car purchase amount']

# %% [markdown]
# ### Scaling

# %%
scale = MinMaxScaler()
X = scale.fit_transform(X)
y = scale.fit_transform(y.values.reshape(-1,1))

# %% [markdown]
# ### spliting Data into train & test

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=True, test_size=.2)

# %%
print('X_train : ', X_train.shape)
print('X_test : ', X_test.shape)
print('y_train : ', y_train.shape)
print('y_test : ', y_test.shape)
# Out:
# X_train :  (400, 4)
# X_test :  (100, 4)
# y_train :  (400, 1)
# y_test :  (100, 1)

# %% [markdown]
# # Model Structure

# %%
model = Sequential([
    Input(shape=(4,)),  # Define the input size here like input_dim=4
    Dense(16, activation='relu'),   #, input_dim=4
    Dense(16, activation='relu'),
    Dense(1, activation='linear')
])

model.compile(optimizer='adam', loss= 'mean_squared_error', metrics=['mean_absolute_error'])
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 16)             │            80 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 369 (1.44 KB)
#  Trainable params: 369 (1.44 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Model training

# %%
history = model.fit(X_train, y_train, validation_split=.2, epochs=50)
# Out:
# Epoch 1/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.1418 - mean_absolute_error: 0.3439 - val_loss: 0.0741 - val_mean_absolute_error: 0.2438
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0629 - mean_absolute_error: 0.2127 - val_loss: 0.0250 - val_mean_absolute_error: 0.1272
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0253 - mean_absolute_error: 0.1265 - val_loss: 0.0186 - val_mean_absolute_error: 0.1081
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0239 - mean_absolute_error: 0.1183 - val_loss: 0.0164 - val_mean_absolute_error: 0.1013
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0213 - mean_absolute_error: 0.1147 - val_loss: 0.0127 - val_mean_absolute_error: 0.0885
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0143 - mean_absolute_error: 0.0949 - val_loss: 0.0107 - val_mean_absolute_error: 0.0798
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0134 - mean_absolute_error: 0.0867 - val_loss: 0.0090 - val_mean_absolute_error: 0.0730
# Epoch 8/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0129 - mean_absolute_error: 0.0874 - val_loss: 0.0077 - val_mean_absolute_error: 0.0679
# Epoch 9/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0112 - mean_absolute_error: 0.0820 - val_loss: 0.0069 - val_mean_absolute_error: 0.0644
# Epoch 10/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0102 - mean_absolute_error: 0.0775 - val_loss: 0.0060 - val_mean_absolute_error: 0.0602
# Epoch 11/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0089 - mean_absolute_error: 0.0717 - val_loss: 0.0054 - val_mean_absolute_error: 0.0569
# Epoch 12/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0080 - mean_absolute_error: 0.0703 - val_loss: 0.0049 - val_mean_absolute_error: 0.0540
# Epoch 13/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0075 - mean_absolute_error: 0.0701 - val_loss: 0.0045 - val_mean_absolute_error: 0.0513
# Epoch 14/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070 - mean_absolute_error: 0.0661 - val_loss: 0.0042 - val_mean_absolute_error: 0.0492
# Epoch 15/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0064 - mean_absolute_error: 0.0621 - val_loss: 0.0039 - val_mean_absolute_error: 0.0474
# Epoch 16/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070 - mean_absolute_error: 0.0628 - val_loss: 0.0036 - val_mean_absolute_error: 0.0456
# Epoch 17/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0052 - mean_absolute_error: 0.0573 - val_loss: 0.0034 - val_mean_absolute_error: 0.0440
# Epoch 18/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0048 - mean_absolute_error: 0.0533 - val_loss: 0.0032 - val_mean_absolute_error: 0.0425
# Epoch 19/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0046 - mean_absolute_error: 0.0519 - val_loss: 0.0029 - val_mean_absolute_error: 0.0417
# Epoch 20/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0048 - mean_absolute_error: 0.0555 - val_loss: 0.0029 - val_mean_absolute_error: 0.0400
# Epoch 21/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0045 - mean_absolute_error: 0.0516 - val_loss: 0.0026 - val_mean_absolute_error: 0.0390
# Epoch 22/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0044 - mean_absolute_error: 0.0509 - val_loss: 0.0024 - val_mean_absolute_error: 0.0379
# Epoch 23/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0037 - mean_absolute_error: 0.0472 - val_loss: 0.0024 - val_mean_absolute_error: 0.0364
# Epoch 24/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0034 - mean_absolute_error: 0.0455 - val_loss: 0.0022 - val_mean_absolute_error: 0.0356
# Epoch 25/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0033 - mean_absolute_error: 0.0448 - val_loss: 0.0021 - val_mean_absolute_error: 0.0342
# Epoch 26/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0032 - mean_absolute_error: 0.0442 - val_loss: 0.0019 - val_mean_absolute_error: 0.0332
# Epoch 27/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0027 - mean_absolute_error: 0.0399 - val_loss: 0.0018 - val_mean_absolute_error: 0.0320
# Epoch 28/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0025 - mean_absolute_error: 0.0394 - val_loss: 0.0017 - val_mean_absolute_error: 0.0310
# Epoch 29/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0024 - mean_absolute_error: 0.0372 - val_loss: 0.0016 - val_mean_absolute_error: 0.0300
# Epoch 30/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0021 - mean_absolute_error: 0.0356 - val_loss: 0.0015 - val_mean_absolute_error: 0.0287
# Epoch 31/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0019 - mean_absolute_error: 0.0340 - val_loss: 0.0014 - val_mean_absolute_error: 0.0277
# Epoch 32/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - mean_absolute_error: 0.0330 - val_loss: 0.0013 - val_mean_absolute_error: 0.0266
# Epoch 33/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0016 - mean_absolute_error: 0.0323 - val_loss: 0.0012 - val_mean_absolute_error: 0.0255
# Epoch 34/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0017 - mean_absolute_error: 0.0323 - val_loss: 0.0011 - val_mean_absolute_error: 0.0244
# Epoch 35/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0015 - mean_absolute_error: 0.0302 - val_loss: 0.0010 - val_mean_absolute_error: 0.0233
# Epoch 36/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0012 - mean_absolute_error: 0.0273 - val_loss: 9.3091e-04 - val_mean_absolute_error: 0.0223
# Epoch 37/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0012 - mean_absolute_error: 0.0278 - val_loss: 8.4710e-04 - val_mean_absolute_error: 0.0212
# Epoch 38/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.7326e-04 - mean_absolute_error: 0.0245 - val_loss: 7.9717e-04 - val_mean_absolute_error: 0.0203
# Epoch 39/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.9222e-04 - mean_absolute_error: 0.0248 - val_loss: 7.1724e-04 - val_mean_absolute_error: 0.0193
# Epoch 40/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.3080e-04 - mean_absolute_error: 0.0219 - val_loss: 6.6327e-04 - val_mean_absolute_error: 0.0183
# Epoch 41/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.3245e-04 - mean_absolute_error: 0.0209 - val_loss: 6.0495e-04 - val_mean_absolute_error: 0.0174
# Epoch 42/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.1283e-04 - mean_absolute_error: 0.0216 - val_loss: 5.4465e-04 - val_mean_absolute_error: 0.0164
# Epoch 43/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.0821e-04 - mean_absolute_error: 0.0205 - val_loss: 5.1059e-04 - val_mean_absolute_error: 0.0156
# Epoch 44/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.9133e-04 - mean_absolute_error: 0.0202 - val_loss: 4.6569e-04 - val_mean_absolute_error: 0.0148
# Epoch 45/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.6485e-04 - mean_absolute_error: 0.0165 - val_loss: 4.1797e-04 - val_mean_absolute_error: 0.0138
# Epoch 46/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.6164e-04 - mean_absolute_error: 0.0164 - val_loss: 3.9138e-04 - val_mean_absolute_error: 0.0132
# Epoch 47/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.4084e-04 - mean_absolute_error: 0.0140 - val_loss: 3.4666e-04 - val_mean_absolute_error: 0.0122
# Epoch 48/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.6334e-04 - mean_absolute_error: 0.0141 - val_loss: 3.2967e-04 - val_mean_absolute_error: 0.0119
# Epoch 49/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7884e-04 - mean_absolute_error: 0.0128 - val_loss: 2.9428e-04 - val_mean_absolute_error: 0.0109
# Epoch 50/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.7588e-04 - mean_absolute_error: 0.0130 - val_loss: 2.7455e-04 - val_mean_absolute_error: 0.0104

# %%
# Define needed variables
tr_acc = history.history['mean_absolute_error']
tr_loss = history.history['loss']
val_acc = history.history['val_mean_absolute_error']
val_loss = history.history['val_loss']
index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmax(val_acc)
acc_highest = val_acc[index_acc]
Epochs = [i+1 for i in range(len(tr_acc))]
loss_label = f'best epoch= {str(index_loss + 1)}'
acc_label = f'best epoch= {str(index_acc + 1)}'

# Plot training history
plt.figure(figsize= (20, 8))
plt.style.use('fivethirtyeight')

plt.subplot(1, 2, 1)
plt.plot(Epochs, tr_loss, 'purple', label= 'Training loss')
plt.plot(Epochs, val_loss, 'y', label= 'Validation loss')
plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'darkblue', label= loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(Epochs, tr_acc, 'purple', label= 'Training Accuracy')
plt.plot(Epochs, val_acc, 'y', label= 'Validation Accuracy')
plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'darkblue', label= acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout
plt.show()

# %% [markdown]
# # Prediction

# %%
y_pred = model.predict(X_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_pred)

# %%
print('r2 score : ', r2)
# Out:
# r2 score :  0.9921836090656823
