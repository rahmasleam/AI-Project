# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import seaborn as sns
sns.set_style('darkgrid')

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Deep learning libraries
import tensorflow as tf
import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Dense, LSTM, Dropout

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Reading The Data

# %%
data_dir = '/kaggle/input/daily-climate-time-series-data/DailyDelhiClimateTrain.csv'
df = pd.read_csv(data_dir, index_col='date', parse_dates=True)

# %% [markdown]
# # Data Exploration

# %%
df.head()
# Out:
#              meantemp   humidity  wind_speed  meanpressure
# date
# 2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 2013-01-05   6.000000  86.833333    3.700000   1016.500000

# %%
df.tail()
# Out:
#              meantemp    humidity  wind_speed  meanpressure
# date
# 2016-12-28  17.217391   68.043478    3.547826   1015.565217
# 2016-12-29  15.238095   87.857143    6.000000   1016.904762
# 2016-12-30  14.095238   89.666667    6.266667   1017.904762
# 2016-12-31  15.052632   87.000000    7.325000   1016.100000
# 2017-01-01  10.000000  100.000000    0.000000   1016.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1462 entries, 2013-01-01 to 2017-01-01
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   meantemp      1462 non-null   float64
#  1   humidity      1462 non-null   float64
#  2   wind_speed    1462 non-null   float64
#  3   meanpressure  1462 non-null   float64
# dtypes: float64(4)
# memory usage: 57.1 KB

# %%
df.describe()
# Out:
#           meantemp     humidity   wind_speed  meanpressure
# count  1462.000000  1462.000000  1462.000000   1462.000000
# mean     25.495521    60.771702     6.802209   1011.104548
# std       7.348103    16.769652     4.561602    180.231668
# min       6.000000    13.428571     0.000000     -3.041667
# 25%      18.857143    50.375000     3.475000   1001.580357
# 50%      27.714286    62.625000     6.221667   1008.563492
# 75%      31.305804    72.218750     9.238235   1014.944901
# max      38.714286   100.000000    42.220000   7679.333333

# %%
plt.figure(figsize=(15, 6))
df['meantemp'].plot()
plt.title("Mean Temperature")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 6))
df['humidity'].plot()
plt.title("Humidity")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 6))
df['wind_speed'].plot()
plt.title("Wind Speed")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 6))
df['meanpressure'].plot()
plt.title("Mean Pressure")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Choosing Prediction Column

# %%
dataset = df['meantemp']
dataset = pd.DataFrame(dataset)

data = dataset.values
data.shape
# Out:
# (1462, 1)

# %% [markdown]
# ## Normalizing Data

# %%
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(data)

# %% [markdown]
# ## Splitting The Data

# %%
# 75% to Train, 25% to Test
train_size = int(len(data) * .75)
test_size = len(data) - train_size

print("Train Size :",train_size,"Test Size :",test_size)
# Out:
# Train Size : 1096 Test Size : 366

# %%
train_data = scaled_data[:train_size, :]
test_data = scaled_data[train_size-60: , :]
train_data.shape
# Out:
# (1096, 1)

# %% [markdown]
# ## Creating training set

# %%
# Creating a Training set with 60 time-steps
x_train = []
y_train = []

for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i, 0])

# %%
# Convert to numpy array
x_train, y_train = np.array(x_train), np.array(y_train)

# %%
# Reshaping the input to (n_samples, time_steps, n_feature)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# %%
x_train.shape, y_train.shape
# Out:
# ((1036, 60, 1), (1036,))

# %% [markdown]
# # LSTM Model

# %% [markdown]
# ## Model Structure

# %%
model = Sequential([
    LSTM(50, return_sequences=True, input_shape = (x_train.shape[1], 1) ),
    LSTM(64, return_sequences=False),
    
    Dense(32),
    Dense(16),
    Dense(1)
])

model.compile(optimizer='adam', loss= 'mse', metrics=['mean_absolute_error'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_2 (LSTM)                   │ (None, 60, 50)         │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 64)             │        29,440 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 42,465 (165.88 KB)
#  Trainable params: 42,465 (165.88 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Model Training

# %%
early_stopping = EarlyStopping(
    patience=10,
    monitor='loss',
    restore_best_weights=True
)

# %%
# Fitting the LSTM to the Training set
history = model.fit(x_train, y_train, epochs=100, batch_size=32, callbacks=early_stopping)
# Out:
# Epoch 1/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - loss: 0.0962 - mean_absolute_error: 0.2283
# Epoch 2/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0087 - mean_absolute_error: 0.0758
# Epoch 3/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0058 - mean_absolute_error: 0.0613
# Epoch 4/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0056 - mean_absolute_error: 0.0590
# Epoch 5/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.0058 - mean_absolute_error: 0.0609
# Epoch 6/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0049 - mean_absolute_error: 0.0553
# Epoch 7/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0048 - mean_absolute_error: 0.0550
# Epoch 8/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0047 - mean_absolute_error: 0.0545
# Epoch 9/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0049 - mean_absolute_error: 0.0551
# Epoch 10/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0047 - mean_absolute_error: 0.0535
# Epoch 11/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0047 - mean_absolute_error: 0.0535
# Epoch 12/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0043 - mean_absolute_error: 0.0518
# Epoch 13/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0039 - mean_absolute_error: 0.0494
# Epoch 14/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0056 - mean_absolute_error: 0.0587
# Epoch 15/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0045 - mean_absolute_error: 0.0526
# Epoch 16/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0037 - mean_absolute_error: 0.0476
# Epoch 17/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0040 - mean_absolute_error: 0.0499
# Epoch 18/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0048 - mean_absolute_error: 0.0541
# Epoch 19/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.0037 - mean_absolute_error: 0.0481
# Epoch 20/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0037 - mean_absolute_error: 0.0479
# Epoch 21/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0039 - mean_absolute_error: 0.0491
# Epoch 22/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0033 - mean_absolute_error: 0.0449
# Epoch 23/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0038 - mean_absolute_error: 0.0477
# Epoch 24/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0035 - mean_absolute_error: 0.0459
# Epoch 25/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0033 - mean_absolute_error: 0.0455
# Epoch 26/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0034 - mean_absolute_error: 0.0458
# Epoch 27/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0034 - mean_absolute_error: 0.0459
# Epoch 28/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0032 - mean_absolute_error: 0.0440
# Epoch 29/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0033 - mean_absolute_error: 0.0436
# Epoch 30/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - loss: 0.0029 - mean_absolute_error: 0.0429
# Epoch 31/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - loss: 0.0032 - mean_absolute_error: 0.0450
# Epoch 32/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0031 - mean_absolute_error: 0.0435
# Epoch 33/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0032 - mean_absolute_error: 0.0440
# Epoch 34/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0029 - mean_absolute_error: 0.0411
# Epoch 35/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0024 - mean_absolute_error: 0.0380
# Epoch 36/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0027 - mean_absolute_error: 0.0409
# Epoch 37/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0027 - mean_absolute_error: 0.0399
# Epoch 38/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0035 - mean_absolute_error: 0.0460
# Epoch 39/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0033 - mean_absolute_error: 0.0444
# Epoch 40/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0030 - mean_absolute_error: 0.0422
# Epoch 41/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0028 - mean_absolute_error: 0.0414
# Epoch 42/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0028 - mean_absolute_error: 0.0410
# Epoch 43/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0028 - mean_absolute_error: 0.0408
# Epoch 44/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.0027 - mean_absolute_error: 0.0403
# Epoch 45/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0030 - mean_absolute_error: 0.0419
# Epoch 46/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0027 - mean_absolute_error: 0.0392
# Epoch 47/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0023 - mean_absolute_error: 0.0374
# Epoch 48/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0026 - mean_absolute_error: 0.0393
# Epoch 49/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0024 - mean_absolute_error: 0.0373
# Epoch 50/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0025 - mean_absolute_error: 0.0385
# Epoch 51/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0026 - mean_absolute_error: 0.0391
# Epoch 52/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0034 - mean_absolute_error: 0.0459
# Epoch 53/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0025 - mean_absolute_error: 0.0384
# Epoch 54/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0028 - mean_absolute_error: 0.0403
# Epoch 55/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0028 - mean_absolute_error: 0.0398
# Epoch 56/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0025 - mean_absolute_error: 0.0382
# Epoch 57/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0024 - mean_absolute_error: 0.0375
# Epoch 58/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0028 - mean_absolute_error: 0.0409
# Epoch 59/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.0026 - mean_absolute_error: 0.0402
# Epoch 60/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0028 - mean_absolute_error: 0.0397
# Epoch 61/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0023 - mean_absolute_error: 0.0362
# Epoch 62/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0026 - mean_absolute_error: 0.0395
# Epoch 63/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0026 - mean_absolute_error: 0.0384
# Epoch 64/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0026 - mean_absolute_error: 0.0385
# Epoch 65/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0024 - mean_absolute_error: 0.0380
# Epoch 66/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0028 - mean_absolute_error: 0.0400
# Epoch 67/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0024 - mean_absolute_error: 0.0382
# Epoch 68/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0026 - mean_absolute_error: 0.0395
# Epoch 69/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0028 - mean_absolute_error: 0.0409
# Epoch 70/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0026 - mean_absolute_error: 0.0391
# Epoch 71/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0026 - mean_absolute_error: 0.0381
# Epoch 72/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0023 - mean_absolute_error: 0.0370
# Epoch 73/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 0.0025 - mean_absolute_error: 0.0374
# Epoch 74/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0023 - mean_absolute_error: 0.0374
# Epoch 75/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - loss: 0.0024 - mean_absolute_error: 0.0379
# Epoch 76/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0027 - mean_absolute_error: 0.0405
# Epoch 77/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0029 - mean_absolute_error: 0.0411
# Epoch 78/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0025 - mean_absolute_error: 0.0376
# Epoch 79/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0025 - mean_absolute_error: 0.0379
# Epoch 80/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0025 - mean_absolute_error: 0.0377
# Epoch 81/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0022 - mean_absolute_error: 0.0361
# Epoch 82/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0027 - mean_absolute_error: 0.0401

# %% [markdown]
# ## Model Evaluation

# %%
plt.figure(figsize=(15,6))
plt.plot(history.history['loss'])
plt.plot(history.history['mean_absolute_error'])
plt.legend(['Mean Squared Error', 'Mean Absolute Error'])
plt.title('Losses')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.show()

# %% [markdown]
# # Predection

# %% [markdown]
# ## Creating testing set

# %%
# Creating a testing set with 60 time-steps and 1 output
x_test = []
y_test = []

for i in range(60, len(test_data)):
    x_test.append(test_data[i-60:i, 0])
    y_test.append(test_data[i, 0])

# %%
x_test, y_test = np.array(x_test), np.array(y_test)

# %%
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
x_test.shape, y_test.shape
# Out:
# ((366, 60, 1), (366,))

# %%
# inverse y_test scaling 
predictions = model.predict(x_test)

# inverse predictions scaling 
predictions = scaler.inverse_transform(predictions)
predictions.shape
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step
# (366, 1)

# %% [markdown]
# ## Root mean square error

# %%
# inverse y_test scaling 
y_test = scaler.inverse_transform([y_test])

RSME = np.sqrt(np.mean( y_test - predictions)**2).round(2)
RSME
# Out:
# 0.18

# %%
preds_acts = pd.DataFrame(data={'Predictions':predictions.flatten(), 'Actuals':y_test.flatten()})
preds_acts
# Out:
#      Predictions    Actuals
# 0      14.875005  14.000000
# 1      14.402603  14.375000
# 2      14.397475  15.750000
# 3      15.119387  15.833333
# 4      15.509225  17.375000
# ..           ...        ...
# 361    16.713837  17.217391
# 362    17.006321  15.238095
# 363    16.029854  14.095238
# 364    15.035577  15.052632
# 365    15.121952  10.000000
#
# [366 rows x 2 columns]

# %%
plt.figure(figsize = (16, 6))
plt.plot(preds_acts['Predictions'])
plt.plot(preds_acts['Actuals'])
plt.legend(['Predictions', 'Actuals'])
plt.show()

# %% [markdown]
# ## Visualize Predictions with The Data

# %%
train = dataset.iloc[:train_size , 0:1]
test = dataset.iloc[train_size: , 0:1]
test['Predictions'] = predictions

plt.figure(figsize= (15, 6))
plt.title('Temperature Prediction', fontsize= 18)
plt.xlabel('Date', fontsize= 18)
plt.ylabel('Temperature', fontsize= 18)
plt.plot(train['meantemp'], linewidth= 3)
plt.plot(test['meantemp'], linewidth= 3)
plt.plot(test["Predictions"], linewidth= 3)
plt.legend(['Train', 'Test', 'Predictions'])
plt.show()

# %% [markdown]
# # Multivariate Predection

# %%
df.head()
# Out:
#              meantemp   humidity  wind_speed  meanpressure
# date
# 2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 2013-01-05   6.000000  86.833333    3.700000   1016.500000

# %%
data = df.values
data.shape
# Out:
# (1462, 4)

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Data Normalization

# %%
scaled_data = scaler.fit_transform(data)

# %% [markdown]
# ### Data Splitting

# %%
train_size = int(len(data) * 0.75)
test_size = len(data) - train_size
print("Train Size :",train_size,"Test Size :",test_size)

train_data = scaled_data[:train_size, :]
test_data = scaled_data[train_size-60:, :]
# Out:
# Train Size : 1096 Test Size : 366

# %%
print('Shape of Train Data : ', train_data.shape)
print('Shape of Test Data', test_data.shape)
# Out:
# Shape of Train Data :  (1096, 4)
# Shape of Test Data (426, 4)

# %% [markdown]
# ### Creating Train Data

# %%
# Creating a Training set with 60 time-steps
x_train = []
y_train = []

for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i, :4])
    y_train.append(train_data[i, :4])

# %%
# Convert to numpy array
x_train, y_train = np.array(x_train), np.array(y_train)

# %%
# Reshaping the input to (n_samples, time_steps, n_feature)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 4))

# %%
x_train.shape, y_train.shape
# Out:
# ((1036, 60, 4), (1036, 4))

# %% [markdown]
# ## Model Structure

# %%
model2 = Sequential([
    LSTM(50, return_sequences= True, input_shape= (x_train.shape[1], 4)),
    LSTM(64, return_sequences= False),
    Dense(32),
    Dense(16),
    Dense(4)
])

model2.compile(optimizer= 'adam', loss= 'mse' , metrics= ["mean_absolute_error"])

# %%
model2.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_8 (LSTM)                   │ (None, 60, 50)         │        11,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_9 (LSTM)                   │ (None, 64)             │        29,440 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 4)              │            68 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 43,116 (168.42 KB)
#  Trainable params: 43,116 (168.42 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Model Training

# %%
early_stopping = EarlyStopping(
    patience=10,
    monitor='loss',
    restore_best_weights=True
)

# %%
# Fitting the LSTM to the Training set
history2 = model2.fit(x_train, y_train, epochs= 100, batch_size= 32, callbacks=early_stopping)
# Out:
# Epoch 1/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - loss: 0.0643 - mean_absolute_error: 0.1875
# Epoch 2/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.0091 - mean_absolute_error: 0.0677
# Epoch 3/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0076 - mean_absolute_error: 0.0588
# Epoch 4/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0084 - mean_absolute_error: 0.0610
# Epoch 5/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0077 - mean_absolute_error: 0.0570
# Epoch 6/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0079 - mean_absolute_error: 0.0579
# Epoch 7/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0070 - mean_absolute_error: 0.0562
# Epoch 8/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0078 - mean_absolute_error: 0.0579
# Epoch 9/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0071 - mean_absolute_error: 0.0551
# Epoch 10/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0074 - mean_absolute_error: 0.0545
# Epoch 11/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0070 - mean_absolute_error: 0.0558
# Epoch 12/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0074 - mean_absolute_error: 0.0571
# Epoch 13/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0072 - mean_absolute_error: 0.0550
# Epoch 14/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0069 - mean_absolute_error: 0.0554
# Epoch 15/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0071 - mean_absolute_error: 0.0559
# Epoch 16/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0066 - mean_absolute_error: 0.0523
# Epoch 17/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.0068 - mean_absolute_error: 0.0535
# Epoch 18/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0072 - mean_absolute_error: 0.0555
# Epoch 19/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0064 - mean_absolute_error: 0.0517
# Epoch 20/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0069 - mean_absolute_error: 0.0540
# Epoch 21/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0062 - mean_absolute_error: 0.0510
# Epoch 22/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0058 - mean_absolute_error: 0.0507
# Epoch 23/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0058 - mean_absolute_error: 0.0490
# Epoch 24/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0063 - mean_absolute_error: 0.0514
# Epoch 25/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0064 - mean_absolute_error: 0.0523
# Epoch 26/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0059 - mean_absolute_error: 0.0494
# Epoch 27/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0062 - mean_absolute_error: 0.0514
# Epoch 28/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0056 - mean_absolute_error: 0.0499
# Epoch 29/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 0.0064 - mean_absolute_error: 0.0526
# Epoch 30/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0054 - mean_absolute_error: 0.0477
# Epoch 31/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0055 - mean_absolute_error: 0.0478
# Epoch 32/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0060 - mean_absolute_error: 0.0497
# Epoch 33/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0055 - mean_absolute_error: 0.0480
# Epoch 34/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.0054 - mean_absolute_error: 0.0483
# Epoch 35/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0057 - mean_absolute_error: 0.0492
# Epoch 36/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0057 - mean_absolute_error: 0.0475
# Epoch 37/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 0.0056 - mean_absolute_error: 0.0483
# Epoch 38/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0050 - mean_absolute_error: 0.0461
# Epoch 39/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - loss: 0.0056 - mean_absolute_error: 0.0480
# Epoch 40/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0051 - mean_absolute_error: 0.0467
# Epoch 41/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0055 - mean_absolute_error: 0.0474
# Epoch 42/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0054 - mean_absolute_error: 0.0476
# Epoch 43/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0054 - mean_absolute_error: 0.0476
# Epoch 44/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0061 - mean_absolute_error: 0.0486
# Epoch 45/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0053 - mean_absolute_error: 0.0482
# Epoch 46/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0058 - mean_absolute_error: 0.0482
# Epoch 47/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0058 - mean_absolute_error: 0.0488
# Epoch 48/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0049 - mean_absolute_error: 0.0458
# Epoch 49/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0054 - mean_absolute_error: 0.0475
# Epoch 50/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0057 - mean_absolute_error: 0.0483
# Epoch 51/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0056 - mean_absolute_error: 0.0483
# Epoch 52/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0055 - mean_absolute_error: 0.0472
# Epoch 53/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0057 - mean_absolute_error: 0.0492
# Epoch 54/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0054 - mean_absolute_error: 0.0473
# Epoch 55/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0052 - mean_absolute_error: 0.0458
# Epoch 56/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0056 - mean_absolute_error: 0.0486
# Epoch 57/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0050 - mean_absolute_error: 0.0461
# Epoch 58/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0056 - mean_absolute_error: 0.0485
# Epoch 59/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.0053 - mean_absolute_error: 0.0471
# Epoch 60/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0051 - mean_absolute_error: 0.0467
# Epoch 61/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0052 - mean_absolute_error: 0.0477
# Epoch 62/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0053 - mean_absolute_error: 0.0465
# Epoch 63/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0052 - mean_absolute_error: 0.0472
# Epoch 64/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0054 - mean_absolute_error: 0.0466
# Epoch 65/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0055 - mean_absolute_error: 0.0474
# Epoch 66/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0053 - mean_absolute_error: 0.0459
# Epoch 67/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0049 - mean_absolute_error: 0.0453
# Epoch 68/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0052 - mean_absolute_error: 0.0467
# Epoch 69/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0065 - mean_absolute_error: 0.0512
# Epoch 70/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0054 - mean_absolute_error: 0.0480
# Epoch 71/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0055 - mean_absolute_error: 0.0463
# Epoch 72/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 0.0050 - mean_absolute_error: 0.0458
# Epoch 73/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0050 - mean_absolute_error: 0.0454
# Epoch 74/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0050 - mean_absolute_error: 0.0445
# Epoch 75/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0052 - mean_absolute_error: 0.0455
# Epoch 76/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0048 - mean_absolute_error: 0.0442
# Epoch 77/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.0056 - mean_absolute_error: 0.0468
# Epoch 78/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0051 - mean_absolute_error: 0.0450
# Epoch 79/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - loss: 0.0050 - mean_absolute_error: 0.0447
# Epoch 80/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0048 - mean_absolute_error: 0.0445
# Epoch 81/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.0050 - mean_absolute_error: 0.0445
# Epoch 82/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0052 - mean_absolute_error: 0.0456
# Epoch 83/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0053 - mean_absolute_error: 0.0480
# Epoch 84/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.0052 - mean_absolute_error: 0.0459
# Epoch 85/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0050 - mean_absolute_error: 0.0448
# Epoch 86/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0052 - mean_absolute_error: 0.0457
# Epoch 87/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0049 - mean_absolute_error: 0.0444
# Epoch 88/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0052 - mean_absolute_error: 0.0449

# %% [markdown]
# ## Model Evaluation

# %%
plt.figure(figsize=(15,6))
plt.plot(history2.history['loss'])
plt.plot(history2.history['mean_absolute_error'])
plt.legend(['Mean Squared Error', 'Mean Absolute Error'])
plt.title('Losses')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.show()

# %% [markdown]
# ## Prediction

# %% [markdown]
# ### Creating Test Data

# %%
# Creating a testing set with 60 time-steps and 1 output
x_test = []
y_test = []

for i in range(60, len(test_data)):
    x_test.append(test_data[i-60:i , :4])
    y_test.append(test_data[i , :4])

# %%
x_test, y_test = np.array(x_test), np.array(y_test)

# %%
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 4))

# %%
x_test.shape , y_test.shape
# Out:
# ((366, 60, 4), (366, 4))

# %%
# Get Prediction
predictions = model2.predict(x_test)

# inverse predictions scaling 
predictions = scaler.inverse_transform(predictions)
predictions.shape
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# (366, 4)

# %%
#inverse y_test scaling
y_test = scaler.inverse_transform(y_test)

# %%
RMSE = np.sqrt(np.mean( y_test - predictions )**2).round(2)
RMSE
# Out:
# 1.3

# %% [markdown]
# # Forecast Next 30 Days

# %%
from datetime import timedelta

# %%
def insert_end(Xin, new_input):
    timestep = 60
    for i in range(timestep - 1):
        Xin[:, i, :] = Xin[:, i+1, :]
    Xin[:, timestep - 1, :] = new_input
    return Xin

# %%
future = 30
forcast = []
Xin = x_test[-1 :, :, :]
time = []

for i in range(0, future):
    out = model2.predict(Xin, batch_size=5)
    forcast.append(out[0]) 
    print(forcast)
    Xin = insert_end(Xin, out[0, 0]) 
    time.append(pd.to_datetime(df.index[-1]) + timedelta(days=i))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# [array([0.35195458, 0.2457679 , 0.07883405, 0.2160769 ], dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [array([0.35195458, 0.2457679 , 0.07883405, 0.2160769 ], dtype=float32), array([0.35195634, 0.24574476, 0.07882468, 0.2160917 ], dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [array([0.35195458, 0.2457679 , 0.07883405, 0.2160769 ], dtype=float32), array([0.35195634, 0.24574476, 0.07882468, 0.2160917 ], dtype=float32), array([0.35196042, 0.24572164, 0.07881831, 0.2161051 ], dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [array([0.35195458, 0.2457679 , 0.07883405, 0.2160769 ], dtype=float32), array([0.35195634, 0.24574476, 0.07882468, 0.2160917 ], dtype=float32), array([0.35196042, 0.24572164, 0.07881831, 0.2161051 ], dtype=float32), array([0.3519667 , 0.2456986 , 0.07881463, 0.2161172 ], dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [array([0.35195458, 0.2457679 , 0.07883405, 0.2160769 ], dtype=float32), array([0.35195634, 0.24574476, 0.07882468, 0.2160917 ], dtype=float32), array([0.35196042, 0.24572164, 0.07881831, 0.2161051 ], dtype=float32), array([0.3519667 , 0.2456986 , 0.07881463, 0.2161172 ], dtype=float32), array([0.35197443, 0.245676  , 0.07881331, 0.21612822], dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [array([0.35195458, 0.2457679 , 0.07883405, 0.2160769 ], dtype=float32), array([0.35195634, 0.24574476, 0.07882468, 0.2160917 ], dtype=float32), array([0.35196042, 0.24572164, 0.07881831, 0.2161051 ], dtype=float32), array([0.3519667 , 0.2456986 , 0.07881463, 0.2161172 ], dtype=float32), array([0.35197443, 0.245676  , 0.07881331, 0.21612822], dtype=float32), array([0.35198417, 0.24565406, 0.07881425, 0.21613805], dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [array([0.35195458, 0.2457679 , 0.07883405, 0.2160769 ], dtype=float32), array([0.35195634, 0.24574476, 0.07882468, 0.2160917 ], dtype=float32), array([0.35196042, 0.24572164, 0.07881831, 0.2161051 ], dtype=float32), array([0.3519667 , 0.2456986 , 0.07881463, 0.2161172 ], dtype=float32), array([0.35197443, 0.245676  , 0.07881331, 0.21612822], dtype=float32), array([0.35198417, 0.24565406, 0.07881425, 0.21613805], dtype=float32), array([0.3519951 , 0.24563254, 0.07881705, 0.21614705], dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [array([0.35195458, 0.2457679 , 0.07883405, 0.2160769 ], dtype=float32), array([0.35195634, 0.24574476, 0.07882468, 0.2160917 ], dtype=float32), array([0.35196042, 0.24572164, 0.07881831, 0.2161051 ], dtype=float32), array([0.3519667 , 0.2456986 , 0.07881463, 0.2161172 ], dtype=float32), array([0.35197443, 0.245676  , 0.07881331, 0.21612822], dtype=float32), array([0.35198417, 0.24565406, 0.07881425, 0.21613805], dtype=float32), array([0.3519951 , 0.24563254, 0.07881705, 0.21614705], dtype=float32), array([0.35200727, 0.2456119 , 0.07882155, 0.21615505], dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [array([0.35195458, 0.2457679 , 0.07883405, 0.2160769 ], dtype=float32), array([0.35195634, 0.24574476, 0.07882468, 0.2160917 ], dtype=float32), array([0.35196042, 0.24572164, 0.07881831, 0.2161051 ], dtype=float32), array([0.3519667 , 0.2456986 , 0.07881463, 0.2161172 ], dtype=float32), array([0.35197443, 0.245676  , 0.07881331, 0.21612822], dtype=float32), array([0.35198417, 0.24565406, 0.07881425, 0.21613805], dtype=float32), array([0.3519951 , 0.24563254, 0.07881705, 0.21614705], dtype=float32), array([0.35200727, 0.2456119 , 0.07882155, 0.21615505], dtype=float32), array([0.35202032, 0.24559209, 0.07882708, 0.21616247], dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [array([0.35195458, 0.2457679 , 0.07883405, 0.2160769 ], dtype=float32), array([0.35195634, 0.24574476, 0.07882468, 0.2160917 ], dtype=float32), array([0.35196042, 0.24572164, 0.07881831, 0.2161051 ], dtype=float32), array([0.3519667 , 0.2456986 , 0.07881463, 0.2161172 ], dtype=float32), array([0.35197443, 0.245676  , 0.07881331, 0.21612822], dtype=float32), array([0.35198417, 0.24565406, 0.07881425, 0.21613805], dtype=float32), array([0.3519951 , 0.24563254, 0.07881705, 0.21614705], dtype=float32), array([0.35200727, 0.2456119 , 0.07882155, 0.21615505], dtype=float32), array([0.35202032, 0.24559209, 0.07882708, 0.21616247], dtype=float32), array([0.35203427, 0.24557298, 0.07883388, 0.21616909], dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [array([0.35195458, 0.2457679 , 0.07883405, 0.2160769 ], dtype=float32), array([0.35195634, 0.24574476, 0.07882468, 0.2160917 ], dtype=float32), array([0.35196042, 0.24572164, 0.07881831, 0.2161051 ], dtype=float32), array([0.3519667 , 0.2456986 , 0.07881463, 0.2161172 ], dtype=float32), array([0.35197443, 0.245676  , 0.07881331, 0.21612822], dtype=float32), array([0.35198417, 0.24565406, 0.07881425, 0.21613805], dtype=float32), array([0.3519951 , 0.24563254, 0.07881705, 0.21614705], dtype=float32), array([0.35200727, 0.2456119 , 0.07882155, 0.21615505], dtype=float32), array([0.35202032, 0.24559209, 0.07882708, 0.21616247], dtype=float32), array([0.35203427, 0.24557298, 0.07883388, 0.21616909], dtype=float32), array([0.35204872, 0.24555509, 0.07884146, 0.21617518], dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [array([0.35195458, 0.2457679 , 0.07883405, 0.2160769 ], dtype=float32), array([0.35195634, 0.24574476, 0.07882468, 0.2160917 ], dtype=float32), array([0.35196042, 0.24572164, 0.07881831, 0.2161051 ], dtype=float32), array([0.3519667 , 0.2456986 , 0.07881463, 0.2161172 ], dtype=float32), array([0.35197443, 0.245676  , 0.07881331, 0.21612822], dtype=float32), array([0.35198417, 0.24565406, 0.07881425, 0.21613805], dtype=float32), array([0.3519951 , 0.24563254, 0.07881705, 0.21614705], dtype=float32), array([0.35200727, 0.2456119 , 0.07882155, 0.21615505], dtype=float32), array([0.35202032, 0.24559209, 0.07882708, 0.21616247], dtype=float32), array([0.35203427, 0.24557298, 0.07883388, 0.21616909], dtype=float32), array([0.35204872, 0.24555509, 0.07884146, 0.21617518], dtype=float32), array([0.35206324, 0.24553806, 0.07884932, 0.21618073], dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [array([0.35195458, 0.2457679 , 0.07883405, 0.2160769 ], dtype=float32), array([0.35195634, 0.24574476, 0.07882468, 0.2160917 ], dtype=float32), array([0.35196042, 0.24572164, 0.07881831, 0.2161051 ], dtype=float32), array([0.3519667 , 0.2456986 , 0.07881463, 0.2161172 ], dtype=float32), array([0.35197443, 0.245676  , 0.07881331, 0.21612822], dtype=float32), array([0.35198417, 0.24565406, 0.07881425, 0.21613805], dtype=float32), array([0.3519951 , 0.24563254, 0.07881705, 0.21614705], dtype=float32), array([0.35200727, 0.2456119 , 0.07882155, 0.21615505], dtype=float32), array([0.35202032, 0.24559209, 0.07882708, 0.21616247], dtype=float32), array([0.35203427, 0.24557298, 0.07883388, 0.21616909], dtype=float32), array([0.35204872, 0.24555509, 0.07884146, 0.21617518], dtype=float32), array([0.35206324, 0.24553806, 0.07884932, 0.21618073], dtype=float32), array([0.35207808, 0.24552192, 0.07885755, 0.21618594], dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [array([0.35195458, 0.2457679 , 0.07883405, 0.2160769 ], dtype=float32), array([0.35195634, 0.24574476, 0.07882468, 0.2160917 ], dtype=float32), array([0.35196042, 0.24572164, 0.07881831, 0.2161051 ], dtype=float32), array([0.3519667 , 0.2456986 , 0.07881463, 0.2161172 ], dtype=float32), array([0.35197443, 0.245676  , 0.07881331, 0.21612822], dtype=float32), array([0.35198417, 0.24565406, 0.07881425, 0.21613805], dtype=float32), array([0.3519951 , 0.24563254, 0.07881705, 0.21614705], dtype=float32), array([0.35200727, 0.2456119 , 0.07882155, 0.21615505], dtype=float32), array([0.35202032, 0.24559209, 0.07882708, 0.21616247], dtype=float32), array([0.35203427, 0.24557298, 0.07883388, 0.21616909], dtype=float32), array([0.35204872, 0.24555509, 0.07884146, 0.21617518], dtype=float32), array([0.35206324, 0.24553806, 0.07884932, 0.21618073], dtype=float32), array([0.35207808, 0.24552192, 0.07885755, 0.21618594], dtype=float32), array([0.35209274, 0.24550699, 0.07886571, 0.2161907 ], dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [array([0.35195458, 0.2457679 , 0.07883405, 0.2160769 ], dtype=float32), array([0.35195634, 0.24574476, 0.07882468, 0.2160917 ], dtype=float32), array([0.35196042, 0.24572164, 0.07881831, 0.2161051 ], dtype=float32), array([0.3519667 , 0.2456986 , 0.07881463, 0.2161172 ], dtype=float32), array([0.35197443, 0.245676  , 0.07881331, 0.21612822], dtype=float32), array([0.35198417, 0.24565406, 0.07881425, 0.21613805], dtype=float32), array([0.3519951 , 0.24563254, 0.07881705, 0.21614705], dtype=float32), array([0.35200727, 0.2456119 , 0.07882155, 0.21615505], dtype=float32), array([0.35202032, 0.24559209, 0.07882708, 0.21616247], dtype=float32), array([0.35203427, 0.24557298, 0.07883388, 0.21616909], dtype=float32), array([0.35204872, 0.24555509, 0.07884146, 0.21617518], dtype=float32), array([0.35206324, 0.24553806, 0.07884932, 0.21618073], dtype=float32), array([0.35207808, 0.24552192, 0.07885755, 0.21618594], dtype=float32), array([0.35209274, 0.24550699, 0.07886571, 0.2161907 ], dtype=float32), array([0.3521071 , 0.24549307, 0.07887384, 0.21619518], dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [array([0.35195458, 0.2457679 , 0.07883405, 0.2160769 ], dtype=float32), array([0.35195634, 0.24574476, 0.07882468, 0.2160917 ], dtype=float32), array([0.35196042, 0.24572164, 0.07881831, 0.2161051 ], dtype=float32), array([0.3519667 , 0.2456986 , 0.07881463, 0.2161172 ], dtype=float32), array([0.35197443, 0.245676  , 0.07881331, 0.21612822], dtype=float32), array([0.35198417, 0.24565406, 0.07881425, 0.21613805], dtype=float32), array([0.3519951 , 0.24563254, 0.07881705, 0.21614705], dtype=float32), array([0.35200727, 0.2456119 , 0.07882155, 0.21615505], dtype=float32), array([0.35202032, 0.24559209, 0.07882708, 0.21616247], dtype=float32), array([0.35203427, 0.24557298, 0.07883388, 0.21616909], dtype=float32), array([0.35204872, 0.24555509, 0.07884146, 0.21617518], dtype=float32), array([0.35206324, 0.24553806, 0.07884932, 0.21618073], dtype=float32), array([0.35207808, 0.24552192, 0.07885755, 0.21618594], dtype=float32), array([0.35209274, 0.24550699, 0.07886571, 0.2161907 ], dtype=float32), array([0.3521071 , 0.24549307, 0.07887384, 0.21619518], dtype=float32), array([0.35212106, 0.24548033, 0.07888154, 0.21619952], dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [array([0.35195458, 0.2457679 , 0.07883405, 0.2160769 ], dtype=float32), array([0.35195634, 0.24574476, 0.07882468, 0.2160917 ], dtype=float32), array([0.35196042, 0.24572164, 0.07881831, 0.2161051 ], dtype=float32), array([0.3519667 , 0.2456986 , 0.07881463, 0.2161172 ], dtype=float32), array([0.35197443, 0.245676  , 0.07881331, 0.21612822], dtype=float32), array([0.35198417, 0.24565406, 0.07881425, 0.21613805], dtype=float32), array([0.3519951 , 0.24563254, 0.07881705, 0.21614705], dtype=float32), array([0.35200727, 0.2456119 , 0.07882155, 0.21615505], dtype=float32), array([0.35202032, 0.24559209, 0.07882708, 0.21616247], dtype=float32), array([0.35203427, 0.24557298, 0.07883388, 0.21616909], dtype=float32), array([0.35204872, 0.24555509, 0.07884146, 0.21617518], dtype=float32), array([0.35206324, 0.24553806, 0.07884932, 0.21618073], dtype=float32), array([0.35207808, 0.24552192, 0.07885755, 0.21618594], dtype=float32), array([0.35209274, 0.24550699, 0.07886571, 0.2161907 ], dtype=float32), array([0.3521071 , 0.24549307, 0.07887384, 0.21619518], dtype=float32), array([0.35212106, 0.24548033, 0.07888154, 0.21619952], dtype=float32), array([0.35213444, 0.24546836, 0.07888883, 0.21620364], dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [array([0.35195458, 0.2457679 , 0.07883405, 0.2160769 ], dtype=float32), array([0.35195634, 0.24574476, 0.07882468, 0.2160917 ], dtype=float32), array([0.35196042, 0.24572164, 0.07881831, 0.2161051 ], dtype=float32), array([0.3519667 , 0.2456986 , 0.07881463, 0.2161172 ], dtype=float32), array([0.35197443, 0.245676  , 0.07881331, 0.21612822], dtype=float32), array([0.35198417, 0.24565406, 0.07881425, 0.21613805], dtype=float32), array([0.3519951 , 0.24563254, 0.07881705, 0.21614705], dtype=float32), array([0.35200727, 0.2456119 , 0.07882155, 0.21615505], dtype=float32), array([0.35202032, 0.24559209, 0.07882708, 0.21616247], dtype=float32), array([0.35203427, 0.24557298, 0.07883388, 0.21616909], dtype=float32), array([0.35204872, 0.24555509, 0.07884146, 0.21617518], dtype=float32), array([0.35206324, 0.24553806, 0.07884932, 0.21618073], dtype=float32), array([0.35207808, 0.24552192, 0.07885755, 0.21618594], dtype=float32), array([0.35209274, 0.24550699, 0.07886571, 0.2161907 ], dtype=float32), array([0.3521071 , 0.24549307, 0.07887384, 0.21619518], dtype=float32), array([0.35212106, 0.24548033, 0.07888154, 0.21619952], dtype=float32), array([0.35213444, 0.24546836, 0.07888883, 0.21620364], dtype=float32), array([0.35214707, 0.24545774, 0.07889546, 0.21620749], dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [array([0.35195458, 0.2457679 , 0.07883405, 0.2160769 ], dtype=float32), array([0.35195634, 0.24574476, 0.07882468, 0.2160917 ], dtype=float32), array([0.35196042, 0.24572164, 0.07881831, 0.2161051 ], dtype=float32), array([0.3519667 , 0.2456986 , 0.07881463, 0.2161172 ], dtype=float32), array([0.35197443, 0.245676  , 0.07881331, 0.21612822], dtype=float32), array([0.35198417, 0.24565406, 0.07881425, 0.21613805], dtype=float32), array([0.3519951 , 0.24563254, 0.07881705, 0.21614705], dtype=float32), array([0.35200727, 0.2456119 , 0.07882155, 0.21615505], dtype=float32), array([0.35202032, 0.24559209, 0.07882708, 0.21616247], dtype=float32), array([0.35203427, 0.24557298, 0.07883388, 0.21616909], dtype=float32), array([0.35204872, 0.24555509, 0.07884146, 0.21617518], dtype=float32), array([0.35206324, 0.24553806, 0.07884932, 0.21618073], dtype=float32), array([0.35207808, 0.24552192, 0.07885755, 0.21618594], dtype=float32), array([0.35209274, 0.24550699, 0.07886571, 0.2161907 ], dtype=float32), array([0.3521071 , 0.24549307, 0.07887384, 0.21619518], dtype=float32), array([0.35212106, 0.24548033, 0.07888154, 0.21619952], dtype=float32), array([0.35213444, 0.24546836, 0.07888883, 0.21620364], dtype=float32), array([0.35214707, 0.24545774, 0.07889546, 0.21620749], dtype=float32), array([0.35215908, 0.24544787, 0.07890166, 0.21621135], dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [array([0.35195458, 0.2457679 , 0.07883405, 0.2160769 ], dtype=float32), array([0.35195634, 0.24574476, 0.07882468, 0.2160917 ], dtype=float32), array([0.35196042, 0.24572164, 0.07881831, 0.2161051 ], dtype=float32), array([0.3519667 , 0.2456986 , 0.07881463, 0.2161172 ], dtype=float32), array([0.35197443, 0.245676  , 0.07881331, 0.21612822], dtype=float32), array([0.35198417, 0.24565406, 0.07881425, 0.21613805], dtype=float32), array([0.3519951 , 0.24563254, 0.07881705, 0.21614705], dtype=float32), array([0.35200727, 0.2456119 , 0.07882155, 0.21615505], dtype=float32), array([0.35202032, 0.24559209, 0.07882708, 0.21616247], dtype=float32), array([0.35203427, 0.24557298, 0.07883388, 0.21616909], dtype=float32), array([0.35204872, 0.24555509, 0.07884146, 0.21617518], dtype=float32), array([0.35206324, 0.24553806, 0.07884932, 0.21618073], dtype=float32), array([0.35207808, 0.24552192, 0.07885755, 0.21618594], dtype=float32), array([0.35209274, 0.24550699, 0.07886571, 0.2161907 ], dtype=float32), array([0.3521071 , 0.24549307, 0.07887384, 0.21619518], dtype=float32), array([0.35212106, 0.24548033, 0.07888154, 0.21619952], dtype=float32), array([0.35213444, 0.24546836, 0.07888883, 0.21620364], dtype=float32), array([0.35214707, 0.24545774, 0.07889546, 0.21620749], dtype=float32), array([0.35215908, 0.24544787, 0.07890166, 0.21621135], dtype=float32), array([0.3521702 , 0.2454387 , 0.07890702, 0.21621503], dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# [array([0.35195458, 0.2457679 , 0.07883405, 0.2160769 ], dtype=float32), array([0.35195634, 0.24574476, 0.07882468, 0.2160917 ], dtype=float32), array([0.35196042, 0.24572164, 0.07881831, 0.2161051 ], dtype=float32), array([0.3519667 , 0.2456986 , 0.07881463, 0.2161172 ], dtype=float32), array([0.35197443, 0.245676  , 0.07881331, 0.21612822], dtype=float32), array([0.35198417, 0.24565406, 0.07881425, 0.21613805], dtype=float32), array([0.3519951 , 0.24563254, 0.07881705, 0.21614705], dtype=float32), array([0.35200727, 0.2456119 , 0.07882155, 0.21615505], dtype=float32), array([0.35202032, 0.24559209, 0.07882708, 0.21616247], dtype=float32), array([0.35203427, 0.24557298, 0.07883388, 0.21616909], dtype=float32), array([0.35204872, 0.24555509, 0.07884146, 0.21617518], dtype=float32), array([0.35206324, 0.24553806, 0.07884932, 0.21618073], dtype=float32), array([0.35207808, 0.24552192, 0.07885755, 0.21618594], dtype=float32), array([0.35209274, 0.24550699, 0.07886571, 0.2161907 ], dtype=float32), array([0.3521071 , 0.24549307, 0.07887384, 0.21619518], dtype=float32), array([0.35212106, 0.24548033, 0.07888154, 0.21619952], dtype=float32), array([0.35213444, 0.24546836, 0.07888883, 0.21620364], dtype=float32), array([0.35214707, 0.24545774, 0.07889546, 0.21620749], dtype=float32), array([0.35215908, 0.24544787, 0.07890166, 0.21621135], dtype=float32), array([0.3521702 , 0.2454387 , 0.07890702, 0.21621503], dtype=float32), array([0.35218048, 0.2454306 , 0.07891173, 0.21621864], dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [array([0.35195458, 0.2457679 , 0.07883405, 0.2160769 ], dtype=float32), array([0.35195634, 0.24574476, 0.07882468, 0.2160917 ], dtype=float32), array([0.35196042, 0.24572164, 0.07881831, 0.2161051 ], dtype=float32), array([0.3519667 , 0.2456986 , 0.07881463, 0.2161172 ], dtype=float32), array([0.35197443, 0.245676  , 0.07881331, 0.21612822], dtype=float32), array([0.35198417, 0.24565406, 0.07881425, 0.21613805], dtype=float32), array([0.3519951 , 0.24563254, 0.07881705, 0.21614705], dtype=float32), array([0.35200727, 0.2456119 , 0.07882155, 0.21615505], dtype=float32), array([0.35202032, 0.24559209, 0.07882708, 0.21616247], dtype=float32), array([0.35203427, 0.24557298, 0.07883388, 0.21616909], dtype=float32), array([0.35204872, 0.24555509, 0.07884146, 0.21617518], dtype=float32), array([0.35206324, 0.24553806, 0.07884932, 0.21618073], dtype=float32), array([0.35207808, 0.24552192, 0.07885755, 0.21618594], dtype=float32), array([0.35209274, 0.24550699, 0.07886571, 0.2161907 ], dtype=float32), array([0.3521071 , 0.24549307, 0.07887384, 0.21619518], dtype=float32), array([0.35212106, 0.24548033, 0.07888154, 0.21619952], dtype=float32), array([0.35213444, 0.24546836, 0.07888883, 0.21620364], dtype=float32), array([0.35214707, 0.24545774, 0.07889546, 0.21620749], dtype=float32), array([0.35215908, 0.24544787, 0.07890166, 0.21621135], dtype=float32), array([0.3521702 , 0.2454387 , 0.07890702, 0.21621503], dtype=float32), array([0.35218048, 0.2454306 , 0.07891173, 0.21621864], dtype=float32), array([0.35218972, 0.24542333, 0.07891561, 0.21622224], dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [array([0.35195458, 0.2457679 , 0.07883405, 0.2160769 ], dtype=float32), array([0.35195634, 0.24574476, 0.07882468, 0.2160917 ], dtype=float32), array([0.35196042, 0.24572164, 0.07881831, 0.2161051 ], dtype=float32), array([0.3519667 , 0.2456986 , 0.07881463, 0.2161172 ], dtype=float32), array([0.35197443, 0.245676  , 0.07881331, 0.21612822], dtype=float32), array([0.35198417, 0.24565406, 0.07881425, 0.21613805], dtype=float32), array([0.3519951 , 0.24563254, 0.07881705, 0.21614705], dtype=float32), array([0.35200727, 0.2456119 , 0.07882155, 0.21615505], dtype=float32), array([0.35202032, 0.24559209, 0.07882708, 0.21616247], dtype=float32), array([0.35203427, 0.24557298, 0.07883388, 0.21616909], dtype=float32), array([0.35204872, 0.24555509, 0.07884146, 0.21617518], dtype=float32), array([0.35206324, 0.24553806, 0.07884932, 0.21618073], dtype=float32), array([0.35207808, 0.24552192, 0.07885755, 0.21618594], dtype=float32), array([0.35209274, 0.24550699, 0.07886571, 0.2161907 ], dtype=float32), array([0.3521071 , 0.24549307, 0.07887384, 0.21619518], dtype=float32), array([0.35212106, 0.24548033, 0.07888154, 0.21619952], dtype=float32), array([0.35213444, 0.24546836, 0.07888883, 0.21620364], dtype=float32), array([0.35214707, 0.24545774, 0.07889546, 0.21620749], dtype=float32), array([0.35215908, 0.24544787, 0.07890166, 0.21621135], dtype=float32), array([0.3521702 , 0.2454387 , 0.07890702, 0.21621503], dtype=float32), array([0.35218048, 0.2454306 , 0.07891173, 0.21621864], dtype=float32), array([0.35218972, 0.24542333, 0.07891561, 0.21622224], dtype=float32), array([0.35219824, 0.24541669, 0.07891886, 0.21622564], dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [array([0.35195458, 0.2457679 , 0.07883405, 0.2160769 ], dtype=float32), array([0.35195634, 0.24574476, 0.07882468, 0.2160917 ], dtype=float32), array([0.35196042, 0.24572164, 0.07881831, 0.2161051 ], dtype=float32), array([0.3519667 , 0.2456986 , 0.07881463, 0.2161172 ], dtype=float32), array([0.35197443, 0.245676  , 0.07881331, 0.21612822], dtype=float32), array([0.35198417, 0.24565406, 0.07881425, 0.21613805], dtype=float32), array([0.3519951 , 0.24563254, 0.07881705, 0.21614705], dtype=float32), array([0.35200727, 0.2456119 , 0.07882155, 0.21615505], dtype=float32), array([0.35202032, 0.24559209, 0.07882708, 0.21616247], dtype=float32), array([0.35203427, 0.24557298, 0.07883388, 0.21616909], dtype=float32), array([0.35204872, 0.24555509, 0.07884146, 0.21617518], dtype=float32), array([0.35206324, 0.24553806, 0.07884932, 0.21618073], dtype=float32), array([0.35207808, 0.24552192, 0.07885755, 0.21618594], dtype=float32), array([0.35209274, 0.24550699, 0.07886571, 0.2161907 ], dtype=float32), array([0.3521071 , 0.24549307, 0.07887384, 0.21619518], dtype=float32), array([0.35212106, 0.24548033, 0.07888154, 0.21619952], dtype=float32), array([0.35213444, 0.24546836, 0.07888883, 0.21620364], dtype=float32), array([0.35214707, 0.24545774, 0.07889546, 0.21620749], dtype=float32), array([0.35215908, 0.24544787, 0.07890166, 0.21621135], dtype=float32), array([0.3521702 , 0.2454387 , 0.07890702, 0.21621503], dtype=float32), array([0.35218048, 0.2454306 , 0.07891173, 0.21621864], dtype=float32), array([0.35218972, 0.24542333, 0.07891561, 0.21622224], dtype=float32), array([0.35219824, 0.24541669, 0.07891886, 0.21622564], dtype=float32), array([0.35220578, 0.24541077, 0.07892127, 0.21622916], dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [array([0.35195458, 0.2457679 , 0.07883405, 0.2160769 ], dtype=float32), array([0.35195634, 0.24574476, 0.07882468, 0.2160917 ], dtype=float32), array([0.35196042, 0.24572164, 0.07881831, 0.2161051 ], dtype=float32), array([0.3519667 , 0.2456986 , 0.07881463, 0.2161172 ], dtype=float32), array([0.35197443, 0.245676  , 0.07881331, 0.21612822], dtype=float32), array([0.35198417, 0.24565406, 0.07881425, 0.21613805], dtype=float32), array([0.3519951 , 0.24563254, 0.07881705, 0.21614705], dtype=float32), array([0.35200727, 0.2456119 , 0.07882155, 0.21615505], dtype=float32), array([0.35202032, 0.24559209, 0.07882708, 0.21616247], dtype=float32), array([0.35203427, 0.24557298, 0.07883388, 0.21616909], dtype=float32), array([0.35204872, 0.24555509, 0.07884146, 0.21617518], dtype=float32), array([0.35206324, 0.24553806, 0.07884932, 0.21618073], dtype=float32), array([0.35207808, 0.24552192, 0.07885755, 0.21618594], dtype=float32), array([0.35209274, 0.24550699, 0.07886571, 0.2161907 ], dtype=float32), array([0.3521071 , 0.24549307, 0.07887384, 0.21619518], dtype=float32), array([0.35212106, 0.24548033, 0.07888154, 0.21619952], dtype=float32), array([0.35213444, 0.24546836, 0.07888883, 0.21620364], dtype=float32), array([0.35214707, 0.24545774, 0.07889546, 0.21620749], dtype=float32), array([0.35215908, 0.24544787, 0.07890166, 0.21621135], dtype=float32), array([0.3521702 , 0.2454387 , 0.07890702, 0.21621503], dtype=float32), array([0.35218048, 0.2454306 , 0.07891173, 0.21621864], dtype=float32), array([0.35218972, 0.24542333, 0.07891561, 0.21622224], dtype=float32), array([0.35219824, 0.24541669, 0.07891886, 0.21622564], dtype=float32), array([0.35220578, 0.24541077, 0.07892127, 0.21622916], dtype=float32), array([0.3522125 , 0.24540538, 0.07892307, 0.2162325 ], dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [array([0.35195458, 0.2457679 , 0.07883405, 0.2160769 ], dtype=float32), array([0.35195634, 0.24574476, 0.07882468, 0.2160917 ], dtype=float32), array([0.35196042, 0.24572164, 0.07881831, 0.2161051 ], dtype=float32), array([0.3519667 , 0.2456986 , 0.07881463, 0.2161172 ], dtype=float32), array([0.35197443, 0.245676  , 0.07881331, 0.21612822], dtype=float32), array([0.35198417, 0.24565406, 0.07881425, 0.21613805], dtype=float32), array([0.3519951 , 0.24563254, 0.07881705, 0.21614705], dtype=float32), array([0.35200727, 0.2456119 , 0.07882155, 0.21615505], dtype=float32), array([0.35202032, 0.24559209, 0.07882708, 0.21616247], dtype=float32), array([0.35203427, 0.24557298, 0.07883388, 0.21616909], dtype=float32), array([0.35204872, 0.24555509, 0.07884146, 0.21617518], dtype=float32), array([0.35206324, 0.24553806, 0.07884932, 0.21618073], dtype=float32), array([0.35207808, 0.24552192, 0.07885755, 0.21618594], dtype=float32), array([0.35209274, 0.24550699, 0.07886571, 0.2161907 ], dtype=float32), array([0.3521071 , 0.24549307, 0.07887384, 0.21619518], dtype=float32), array([0.35212106, 0.24548033, 0.07888154, 0.21619952], dtype=float32), array([0.35213444, 0.24546836, 0.07888883, 0.21620364], dtype=float32), array([0.35214707, 0.24545774, 0.07889546, 0.21620749], dtype=float32), array([0.35215908, 0.24544787, 0.07890166, 0.21621135], dtype=float32), array([0.3521702 , 0.2454387 , 0.07890702, 0.21621503], dtype=float32), array([0.35218048, 0.2454306 , 0.07891173, 0.21621864], dtype=float32), array([0.35218972, 0.24542333, 0.07891561, 0.21622224], dtype=float32), array([0.35219824, 0.24541669, 0.07891886, 0.21622564], dtype=float32), array([0.35220578, 0.24541077, 0.07892127, 0.21622916], dtype=float32), array([0.3522125 , 0.24540538, 0.07892307, 0.2162325 ], dtype=float32), array([0.35221833, 0.24540058, 0.07892419, 0.2162358 ], dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [array([0.35195458, 0.2457679 , 0.07883405, 0.2160769 ], dtype=float32), array([0.35195634, 0.24574476, 0.07882468, 0.2160917 ], dtype=float32), array([0.35196042, 0.24572164, 0.07881831, 0.2161051 ], dtype=float32), array([0.3519667 , 0.2456986 , 0.07881463, 0.2161172 ], dtype=float32), array([0.35197443, 0.245676  , 0.07881331, 0.21612822], dtype=float32), array([0.35198417, 0.24565406, 0.07881425, 0.21613805], dtype=float32), array([0.3519951 , 0.24563254, 0.07881705, 0.21614705], dtype=float32), array([0.35200727, 0.2456119 , 0.07882155, 0.21615505], dtype=float32), array([0.35202032, 0.24559209, 0.07882708, 0.21616247], dtype=float32), array([0.35203427, 0.24557298, 0.07883388, 0.21616909], dtype=float32), array([0.35204872, 0.24555509, 0.07884146, 0.21617518], dtype=float32), array([0.35206324, 0.24553806, 0.07884932, 0.21618073], dtype=float32), array([0.35207808, 0.24552192, 0.07885755, 0.21618594], dtype=float32), array([0.35209274, 0.24550699, 0.07886571, 0.2161907 ], dtype=float32), array([0.3521071 , 0.24549307, 0.07887384, 0.21619518], dtype=float32), array([0.35212106, 0.24548033, 0.07888154, 0.21619952], dtype=float32), array([0.35213444, 0.24546836, 0.07888883, 0.21620364], dtype=float32), array([0.35214707, 0.24545774, 0.07889546, 0.21620749], dtype=float32), array([0.35215908, 0.24544787, 0.07890166, 0.21621135], dtype=float32), array([0.3521702 , 0.2454387 , 0.07890702, 0.21621503], dtype=float32), array([0.35218048, 0.2454306 , 0.07891173, 0.21621864], dtype=float32), array([0.35218972, 0.24542333, 0.07891561, 0.21622224], dtype=float32), array([0.35219824, 0.24541669, 0.07891886, 0.21622564], dtype=float32), array([0.35220578, 0.24541077, 0.07892127, 0.21622916], dtype=float32), array([0.3522125 , 0.24540538, 0.07892307, 0.2162325 ], dtype=float32), array([0.35221833, 0.24540058, 0.07892419, 0.2162358 ], dtype=float32), array([0.35222337, 0.24539606, 0.07892486, 0.21623904], dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [array([0.35195458, 0.2457679 , 0.07883405, 0.2160769 ], dtype=float32), array([0.35195634, 0.24574476, 0.07882468, 0.2160917 ], dtype=float32), array([0.35196042, 0.24572164, 0.07881831, 0.2161051 ], dtype=float32), array([0.3519667 , 0.2456986 , 0.07881463, 0.2161172 ], dtype=float32), array([0.35197443, 0.245676  , 0.07881331, 0.21612822], dtype=float32), array([0.35198417, 0.24565406, 0.07881425, 0.21613805], dtype=float32), array([0.3519951 , 0.24563254, 0.07881705, 0.21614705], dtype=float32), array([0.35200727, 0.2456119 , 0.07882155, 0.21615505], dtype=float32), array([0.35202032, 0.24559209, 0.07882708, 0.21616247], dtype=float32), array([0.35203427, 0.24557298, 0.07883388, 0.21616909], dtype=float32), array([0.35204872, 0.24555509, 0.07884146, 0.21617518], dtype=float32), array([0.35206324, 0.24553806, 0.07884932, 0.21618073], dtype=float32), array([0.35207808, 0.24552192, 0.07885755, 0.21618594], dtype=float32), array([0.35209274, 0.24550699, 0.07886571, 0.2161907 ], dtype=float32), array([0.3521071 , 0.24549307, 0.07887384, 0.21619518], dtype=float32), array([0.35212106, 0.24548033, 0.07888154, 0.21619952], dtype=float32), array([0.35213444, 0.24546836, 0.07888883, 0.21620364], dtype=float32), array([0.35214707, 0.24545774, 0.07889546, 0.21620749], dtype=float32), array([0.35215908, 0.24544787, 0.07890166, 0.21621135], dtype=float32), array([0.3521702 , 0.2454387 , 0.07890702, 0.21621503], dtype=float32), array([0.35218048, 0.2454306 , 0.07891173, 0.21621864], dtype=float32), array([0.35218972, 0.24542333, 0.07891561, 0.21622224], dtype=float32), array([0.35219824, 0.24541669, 0.07891886, 0.21622564], dtype=float32), array([0.35220578, 0.24541077, 0.07892127, 0.21622916], dtype=float32), array([0.3522125 , 0.24540538, 0.07892307, 0.2162325 ], dtype=float32), array([0.35221833, 0.24540058, 0.07892419, 0.2162358 ], dtype=float32), array([0.35222337, 0.24539606, 0.07892486, 0.21623904], dtype=float32), array([0.35222775, 0.2453922 , 0.0789249 , 0.21624218], dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [array([0.35195458, 0.2457679 , 0.07883405, 0.2160769 ], dtype=float32), array([0.35195634, 0.24574476, 0.07882468, 0.2160917 ], dtype=float32), array([0.35196042, 0.24572164, 0.07881831, 0.2161051 ], dtype=float32), array([0.3519667 , 0.2456986 , 0.07881463, 0.2161172 ], dtype=float32), array([0.35197443, 0.245676  , 0.07881331, 0.21612822], dtype=float32), array([0.35198417, 0.24565406, 0.07881425, 0.21613805], dtype=float32), array([0.3519951 , 0.24563254, 0.07881705, 0.21614705], dtype=float32), array([0.35200727, 0.2456119 , 0.07882155, 0.21615505], dtype=float32), array([0.35202032, 0.24559209, 0.07882708, 0.21616247], dtype=float32), array([0.35203427, 0.24557298, 0.07883388, 0.21616909], dtype=float32), array([0.35204872, 0.24555509, 0.07884146, 0.21617518], dtype=float32), array([0.35206324, 0.24553806, 0.07884932, 0.21618073], dtype=float32), array([0.35207808, 0.24552192, 0.07885755, 0.21618594], dtype=float32), array([0.35209274, 0.24550699, 0.07886571, 0.2161907 ], dtype=float32), array([0.3521071 , 0.24549307, 0.07887384, 0.21619518], dtype=float32), array([0.35212106, 0.24548033, 0.07888154, 0.21619952], dtype=float32), array([0.35213444, 0.24546836, 0.07888883, 0.21620364], dtype=float32), array([0.35214707, 0.24545774, 0.07889546, 0.21620749], dtype=float32), array([0.35215908, 0.24544787, 0.07890166, 0.21621135], dtype=float32), array([0.3521702 , 0.2454387 , 0.07890702, 0.21621503], dtype=float32), array([0.35218048, 0.2454306 , 0.07891173, 0.21621864], dtype=float32), array([0.35218972, 0.24542333, 0.07891561, 0.21622224], dtype=float32), array([0.35219824, 0.24541669, 0.07891886, 0.21622564], dtype=float32), array([0.35220578, 0.24541077, 0.07892127, 0.21622916], dtype=float32), array([0.3522125 , 0.24540538, 0.07892307, 0.2162325 ], dtype=float32), array([0.35221833, 0.24540058, 0.07892419, 0.2162358 ], dtype=float32), array([0.35222337, 0.24539606, 0.07892486, 0.21623904], dtype=float32), array([0.35222775, 0.2453922 , 0.0789249 , 0.21624218], dtype=float32), array([0.35223138, 0.24538854, 0.07892455, 0.21624534], dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [array([0.35195458, 0.2457679 , 0.07883405, 0.2160769 ], dtype=float32), array([0.35195634, 0.24574476, 0.07882468, 0.2160917 ], dtype=float32), array([0.35196042, 0.24572164, 0.07881831, 0.2161051 ], dtype=float32), array([0.3519667 , 0.2456986 , 0.07881463, 0.2161172 ], dtype=float32), array([0.35197443, 0.245676  , 0.07881331, 0.21612822], dtype=float32), array([0.35198417, 0.24565406, 0.07881425, 0.21613805], dtype=float32), array([0.3519951 , 0.24563254, 0.07881705, 0.21614705], dtype=float32), array([0.35200727, 0.2456119 , 0.07882155, 0.21615505], dtype=float32), array([0.35202032, 0.24559209, 0.07882708, 0.21616247], dtype=float32), array([0.35203427, 0.24557298, 0.07883388, 0.21616909], dtype=float32), array([0.35204872, 0.24555509, 0.07884146, 0.21617518], dtype=float32), array([0.35206324, 0.24553806, 0.07884932, 0.21618073], dtype=float32), array([0.35207808, 0.24552192, 0.07885755, 0.21618594], dtype=float32), array([0.35209274, 0.24550699, 0.07886571, 0.2161907 ], dtype=float32), array([0.3521071 , 0.24549307, 0.07887384, 0.21619518], dtype=float32), array([0.35212106, 0.24548033, 0.07888154, 0.21619952], dtype=float32), array([0.35213444, 0.24546836, 0.07888883, 0.21620364], dtype=float32), array([0.35214707, 0.24545774, 0.07889546, 0.21620749], dtype=float32), array([0.35215908, 0.24544787, 0.07890166, 0.21621135], dtype=float32), array([0.3521702 , 0.2454387 , 0.07890702, 0.21621503], dtype=float32), array([0.35218048, 0.2454306 , 0.07891173, 0.21621864], dtype=float32), array([0.35218972, 0.24542333, 0.07891561, 0.21622224], dtype=float32), array([0.35219824, 0.24541669, 0.07891886, 0.21622564], dtype=float32), array([0.35220578, 0.24541077, 0.07892127, 0.21622916], dtype=float32), array([0.3522125 , 0.24540538, 0.07892307, 0.2162325 ], dtype=float32), array([0.35221833, 0.24540058, 0.07892419, 0.2162358 ], dtype=float32), array([0.35222337, 0.24539606, 0.07892486, 0.21623904], dtype=float32), array([0.35222775, 0.2453922 , 0.0789249 , 0.21624218], dtype=float32), array([0.35223138, 0.24538854, 0.07892455, 0.21624534], dtype=float32), array([0.3522344 , 0.24538521, 0.07892367, 0.21624836], dtype=float32)]

# %%
time
# Out:
# [Timestamp('2017-01-01 00:00:00'),
#  Timestamp('2017-01-02 00:00:00'),
#  Timestamp('2017-01-03 00:00:00'),
#  Timestamp('2017-01-04 00:00:00'),
#  Timestamp('2017-01-05 00:00:00'),
#  Timestamp('2017-01-06 00:00:00'),
#  Timestamp('2017-01-07 00:00:00'),
#  Timestamp('2017-01-08 00:00:00'),
#  Timestamp('2017-01-09 00:00:00'),
#  Timestamp('2017-01-10 00:00:00'),
#  Timestamp('2017-01-11 00:00:00'),
#  Timestamp('2017-01-12 00:00:00'),
#  Timestamp('2017-01-13 00:00:00'),
#  Timestamp('2017-01-14 00:00:00'),
#  Timestamp('2017-01-15 00:00:00'),
#  Timestamp('2017-01-16 00:00:00'),
#  Timestamp('2017-01-17 00:00:00'),
#  Timestamp('2017-01-18 00:00:00'),
#  Timestamp('2017-01-19 00:00:00'),
#  Timestamp('2017-01-20 00:00:00'),
#  Timestamp('2017-01-21 00:00:00'),
#  Timestamp('2017-01-22 00:00:00'),
#  Timestamp('2017-01-23 00:00:00'),
#  Timestamp('2017-01-24 00:00:00'),
#  Timestamp('2017-01-25 00:00:00'),
#  Timestamp('2017-01-26 00:00:00'),
#  Timestamp('2017-01-27 00:00:00'),
#  Timestamp('2017-01-28 00:00:00'),
#  Timestamp('2017-01-29 00:00:00'),
#  Timestamp('2017-01-30 00:00:00')]

# %%
forcast
# Out:
# [array([0.35195458, 0.2457679 , 0.07883405, 0.2160769 ], dtype=float32),
#  array([0.35195634, 0.24574476, 0.07882468, 0.2160917 ], dtype=float32),
#  array([0.35196042, 0.24572164, 0.07881831, 0.2161051 ], dtype=float32),
#  array([0.3519667 , 0.2456986 , 0.07881463, 0.2161172 ], dtype=float32),
#  array([0.35197443, 0.245676  , 0.07881331, 0.21612822], dtype=float32),
#  array([0.35198417, 0.24565406, 0.07881425, 0.21613805], dtype=float32),
#  array([0.3519951 , 0.24563254, 0.07881705, 0.21614705], dtype=float32),
#  array([0.35200727, 0.2456119 , 0.07882155, 0.21615505], dtype=float32),
#  array([0.35202032, 0.24559209, 0.07882708, 0.21616247], dtype=float32),
#  array([0.35203427, 0.24557298, 0.07883388, 0.21616909], dtype=float32),
#  array([0.35204872, 0.24555509, 0.07884146, 0.21617518], dtype=float32),
#  array([0.35206324, 0.24553806, 0.07884932, 0.21618073], dtype=float32),
#  array([0.35207808, 0.24552192, 0.07885755, 0.21618594], dtype=float32),
#  array([0.35209274, 0.24550699, 0.07886571, 0.2161907 ], dtype=float32),
#  array([0.3521071 , 0.24549307, 0.07887384, 0.21619518], dtype=float32),
#  array([0.35212106, 0.24548033, 0.07888154, 0.21619952], dtype=float32),
#  array([0.35213444, 0.24546836, 0.07888883, 0.21620364], dtype=float32),
#  array([0.35214707, 0.24545774, 0.07889546, 0.21620749], dtype=float32),
#  array([0.35215908, 0.24544787, 0.07890166, 0.21621135], dtype=float32),
#  array([0.3521702 , 0.2454387 , 0.07890702, 0.21621503], dtype=float32),
#  array([0.35218048, 0.2454306 , 0.07891173, 0.21621864], dtype=float32),
#  array([0.35218972, 0.24542333, 0.07891561, 0.21622224], dtype=float32),
#  array([0.35219824, 0.24541669, 0.07891886, 0.21622564], dtype=float32),
#  array([0.35220578, 0.24541077, 0.07892127, 0.21622916], dtype=float32),
#  array([0.3522125 , 0.24540538, 0.07892307, 0.2162325 ], dtype=float32),
#  array([0.35221833, 0.24540058, 0.07892419, 0.2162358 ], dtype=float32),
#  array([0.35222337, 0.24539606, 0.07892486, 0.21623904], dtype=float32),
#  array([0.35222775, 0.2453922 , 0.0789249 , 0.21624218], dtype=float32),
#  array([0.35223138, 0.24538854, 0.07892455, 0.21624534], dtype=float32),
#  array([0.3522344 , 0.24538521, 0.07892367, 0.21624836], dtype=float32)]

# %%
forcasted_output = np.array(forcast)
forcasted_output = scaler.inverse_transform(forcasted_output)

# %%
forcasted_output = pd.DataFrame(forcasted_output)
date = pd.DataFrame(time)
df_result = pd.concat([date,forcasted_output], axis=1)
df_result.columns = "Date", 'meantemp', 'humidity', 'wind_speed', 'meanpressure'
df_result.head()
# Out:
#         Date   meantemp   humidity  wind_speed  meanpressure
# 0 2017-01-01  17.513943  34.705048    3.328374   1656.942139
# 1 2017-01-02  17.514000  34.703049    3.327978   1657.055908
# 2 2017-01-03  17.514133  34.701046    3.327709   1657.158813
# 3 2017-01-04  17.514339  34.699051    3.327554   1657.251709
# 4 2017-01-05  17.514591  34.697094    3.327498   1657.336304

# %%
df_result.set_index('Date', inplace=True)

# %%
df_result.head()
# Out:
#              meantemp   humidity  wind_speed  meanpressure
# Date
# 2017-01-01  17.513943  34.705048    3.328374   1656.942139
# 2017-01-02  17.514000  34.703049    3.327978   1657.055908
# 2017-01-03  17.514133  34.701046    3.327709   1657.158813
# 2017-01-04  17.514339  34.699051    3.327554   1657.251709
# 2017-01-05  17.514591  34.697094    3.327498   1657.336304

# %%
plt.figure(figsize=(20, 10))
plt.title('Next 30 Days')

plt.subplot(2, 2, 1)
plt.plot(df['meantemp'])
plt.plot(df_result[['meantemp']])
plt.xlabel('Date', fontsize=18)
plt.ylabel('Temp' ,fontsize=18)

plt.subplot(2, 2, 2)
plt.plot(df['humidity'])
plt.plot(df_result[['humidity']])
plt.xlabel('Date', fontsize=18)
plt.ylabel('humidity' ,fontsize=18)

plt.subplot(2, 2, 3)
plt.plot(df['wind_speed'])
plt.plot(df_result[['wind_speed']])
plt.xlabel('Date', fontsize=18)
plt.ylabel('wind_speed' ,fontsize=18)

plt.subplot(2, 2, 4)
plt.plot(df['meanpressure'])
plt.plot(df_result[['meanpressure']])
plt.xlabel('Date', fontsize=18)
plt.ylabel('meanpressure' ,fontsize=18)

plt.tight_layout()
plt.show()
